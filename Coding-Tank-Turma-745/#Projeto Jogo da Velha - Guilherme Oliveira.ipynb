# %%
#Projeto Jogo da Velha - Guilherme Oliveira
def comando_jogador01():
    l1 = input(f'\nJogador 01. Digite a Linha que deseja jogar: ')
    c1 = input('Jogador 01. Digite a Coluna que deseja jogar: ')
    jogador01 = l1+c1
    jogador01 = int(jogador01)
    return(jogador01)
def comando_jogador02():
    l2 = input(f'\nJogador 02. Digite a Linha que deseja jogar: ')
    c2 = input('Jogador 02. Digite a Coluna que deseja jogar: ')
    jogador02 = l2+c2
    jogador02 = int(jogador02)
    return(jogador02)
def lista_posicoes_jogador01(jogadas):
    lista_posicao_jogadas.append(jogada_J01)
    return(lista_posicao_jogadas)
def lista_posicoes_jogador02(jogadas):
    lista_posicao_jogadas.append(jogada_J02)
    return(lista_posicao_jogadas)
def jogada_jogador01(jogada_J01):
    if jogada_J01 == 11 and linha01[0] != 'X' and linha01[0] != 'O':
        linha01[0] = 'O'
    elif jogada_J01 == 12 and linha01[2] != 'X' and linha01[2] != 'O':
        linha01[2] = 'O'
    elif jogada_J01 == 13 and linha01[4] != 'X' and linha01[4] != 'O':
        linha01[4] = 'O'
    elif jogada_J01 == 21 and linha02[0] != 'X' and linha02[0] != 'O':
        linha02[0] = 'O'
    elif jogada_J01 == 22 and linha02[2] != 'X' and linha02[2] != 'O':
        linha02[2] = 'O'
    elif jogada_J01 == 23 and linha02[4] != 'X' and linha02[4] != 'O':
        linha02[4] = 'O'
    elif jogada_J01 == 31 and linha03[0] != 'X' and linha03[0] != 'O':
        linha03[0] = 'O'
    elif jogada_J01 == 32 and linha03[2] != 'X' and linha03[2] != 'O':
        linha03[2] = 'O'
    elif jogada_J01 == 33 and linha03[4] != 'X' and linha03[4] != 'O':
        linha03[4] = 'O'
def jogada_jogador02(jogada_J02):
    if jogada_J02 == 11 and linha01[0] != 'X' and linha01[0] != 'O':
        linha01[0] = 'X'
    elif jogada_J02 == 12 and linha01[2] != 'X' and linha01[2] != 'O':
        linha01[2] = 'X'
    elif jogada_J02 == 13 and linha01[4] != 'X' and linha01[4] != 'O':
        linha01[4] = 'X'
    elif jogada_J02 == 21 and linha02[0] != 'X' and linha02[0] != 'O':
        linha02[0] = 'X'
    elif jogada_J02 == 22 and linha02[2] != 'X' and linha02[2] != 'O':
        linha02[2] = 'X'
    elif jogada_J02 == 23 and linha02[4] != 'X' and linha02[4] != 'O':
        linha02[4] = 'X'
    elif jogada_J02 == 31 and linha03[0] != 'X' and linha03[0] != 'O':
        linha03[0] = 'X'
    elif jogada_J02 == 32 and linha03[2] != 'X' and linha03[2] != 'O':
        linha03[2] = 'X'
    elif jogada_J02 == 33 and linha03[4] != 'X' and linha03[4] != 'O':
        linha03[4] = 'X'
def print_tabuleiro(linha01,linha02,linha03):
    aspas = ''
    linha01 = aspas.join(linha01)
    linha02 = aspas.join(linha02)
    linha03 = aspas.join(linha03)
    print(f'\n')
    print(linha01)
    print(linha02)
    print(linha03)
def print_vitorioso(linha01,linha02,linha03):
    if linha01 == ['O','|','O','|','O'] or linha02 == ['O','|','O','|','O'] or linha03 == ['O','|','O','|','O']: 
        print(f'\nVitória do jogador 01')
        linha01[0] = 'parada'
    elif linha01 == ['X','|','X','|','X'] or linha02 == ['X','|','X','|','X'] or linha03 == ['X','|','X','|','X']:
        print(f'\nVitória do jogador 02')
        linha01[0] = 'parada'   
    if linha01[0] == 'O' and linha02[0] == 'O' and linha03[0] == 'O':
        print(f'\nVitória do jogador 01')
        linha01[0] = 'parada'
    elif linha01[0] == 'X' and linha02[0] == 'X' and linha03[0] == 'X':
        print(f'\nVitória do jogador 02')
        linha01[0] = 'parada'
    if linha01[2] == 'O' and linha02[2] == 'O' and linha03[2] == 'O':
        print(f'\nVitória do jogador 01')
        linha01[0] = 'parada'
    elif linha01[2] == 'X' and linha02[2] == 'X' and linha03[2] == 'X':
        print(f'\nVitória do jogador 02')
        linha01[0] = 'parada'
    if linha01[4] == 'O' and linha02[4] == 'O' and linha03[4] == 'O':
        print(f'\nVitória do jogador 01')
        linha01[0] = 'parada'
    elif linha01[4] == 'X' and linha02[4] == 'X' and linha03[4] == 'X':
        print(f'\nVitória do jogador 02')
        linha01[0] = 'parada'
    if linha01[0] == 'O' and linha02[2] == 'O' and linha03[4] == 'O':
        print(f'\nVitória do jogador 01')
        linha01[0] = 'parada'
    elif linha01[0] == 'X' and linha02[2] == 'X' and linha03[4] == 'X':
        print(f'\nVitória do jogador 02')
        linha01[0] = 'parada'
    if linha01[4] == 'O' and linha02[2] == 'O' and linha03[0] == 'O':
        print(f'\nVitória do jogador 01')
        linha01[0] = 'parada'
    elif linha01[4] == 'X' and linha02[2] == 'X' and linha03[0] == 'X':
        print(f'\nVitória do jogador 02')
        linha01[0] = 'parada'
def print_empate(contador):
    if contador == 4:
        print(f'\nEmpate!')
linha01 = ['_','|','_','|','_']
linha02 = ['_','|','_','|','_']
linha03 = [' ','|',' ','|',' ']

lista_posicao_jogadas = []
contador = 0

while contador <= 4:
    jogada_J01 = comando_jogador01()
    if (jogada_J01 in lista_posicao_jogadas) and (contador > 0):
        print(f'\n***Não pode jogar em posição já ocupada') 
        jogada_J01 = comando_jogador01()
    lista_posicoes_jogador01(jogada_J01)
    jogada_jogador01(jogada_J01)
    print_tabuleiro(linha01,linha02,linha03)
    print_vitorioso(linha01,linha02,linha03)
    if linha01[0] == 'parada':
        break
    print_empate(contador)         
    if not(contador) == 4:
        jogada_J02 = comando_jogador02()
        if (jogada_J02 in lista_posicao_jogadas):
            print(f'\n***Não pode jogar em posição já ocupada') 
            jogada_J02 = comando_jogador02()
        lista_posicoes_jogador02(jogada_J02)
        jogada_jogador02(jogada_J02)
        print_tabuleiro(linha01,linha02,linha03)
        print_vitorioso(linha01,linha02,linha03)
        if linha01[0] == 'parada':
            break              
    contador += 1
